# %%
import math
def calculate_unit_price(diameter, price):
    radius_m = (diameter / 2) / 100
    area = math.pi * (radius_m ** 2)
    return price / area
def main_pizza():
    d1 = float(input("Enter diameter of pizza 1 (cm): "))
    p1 = float(input("Enter price of pizza 1 (USD): "))
    d2 = float(input("Enter diameter of pizza 2 (cm): "))
    p2 = float(input("Enter price of pizza 2 (USD): "))
    unit_price1 = calculate_unit_price(d1, p1)
    unit_price2 = calculate_unit_price(d2, p2)
    print(f"Unit price 1: {unit_price1:.2f} USD/m2")
    print(f"Unit price 2: {unit_price2:.2f} USD/m2")
    if unit_price1 < unit_price2:
        print("Pizza 1 provides better value.")
    else:
        print("Pizza 2 provides better value.")
if __name__ == "__main__":
    main_pizza()
# Out:
# Unit price 1: 318.31 USD/m2
# Unit price 2: 288.72 USD/m2
# Pizza 2 provides better value.
