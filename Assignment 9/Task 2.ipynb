# %%
filename = input("Enter the name of the file you want to search for: ")
keyword = input("Enter the keywords you want to search for: ")
line_numbers = []

try:
    with open(filename, 'r') as file:
        for line_num, line in enumerate(file, start=1):
            if keyword in line:
                line_numbers.append(line_num)
    print(f"Keywords appear in the following lines: {line_numbers}")
except FileNotFoundError:
    print("File not found.")
# Out:
# Keywords appear in the following lines: [2]
