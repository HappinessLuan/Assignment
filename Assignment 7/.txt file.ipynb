# %%
time = "It took approximately 5 hours to work on this assignment."
with open("time_spent.txt", "w", encoding="utf-8") as file:
    file.write(time)
print("File 'time_spent.txt' It has been successfully created!")
# Out:
# File 'time_spent.txt' It has been successfully created!
